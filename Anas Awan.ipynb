# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# **ANAS KHALID AWAN**
# DATA SCIENTIST

# %% [markdown]
# *As I heard about the data science, four months back, I decided to be a Data Scientist and excel in the field due to number of reasons which includes handsome salary package, relaxed working enviornment, remote job opportunities etc.*

# %% [markdown]
# ### My code in the following cell will declare the variables and then add them

# %%
import numpy
apple=3
orange=12
print (apple+orange)
# Out:
# 15

# %% [markdown]
# - Item 1
# - Item 2
# - Item 3
#
#
# 1. item 4
# 2. item 5
# 3. item 6
#
# | Name | Age | Gender |
# | ---- | --- | ------ |
# | Khan | 30  | Male   |
# | Jane | 25  | Female |
